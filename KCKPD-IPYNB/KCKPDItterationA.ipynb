# %%
#pip install pandas

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_excel("C://Users//hlcma//OneDrive//Desktop//KCKPD/KCKPD-YTD-STATS-1-15-24/KCKPD-YTD-STATS-1-15-24.xlsx", header=2)
## Header is of two rows with the Pivot table
## Reference Link: https://stackoverflow.com/questions/37400974/error-unicode-error-unicodeescape-codec-cant-decode-bytes-in-position-2-3
## Reference Link: https://saturncloud.io/blog/how-to-use-python-and-pandas-to-convert-xlsx-to-csv-and-remove-the-index-column/

# %%
df
# Out:
#                         01/15   2016     2017  2018  Unnamed: 4  2019  \
# 0                    Homicide      2      0.0   2.0         NaN   1.0
# 1                        Rape     15      8.0  13.0         NaN   2.0
# 2                 Agg Battery      9      9.0   7.0         NaN  15.0
# 3                 Agg Assault     16     16.0  13.0         NaN  11.0
# 4    Shooting Into Dwell/Auto     16     19.0  18.0         NaN   8.0
# ..                        ...    ...      ...   ...         ...   ...
# 110                     Other    588    708.0   NaN      1391.0   NaN
# 111   TOTAL NON-TARGET CRIMES   9294   9629.0   NaN      9668.0   NaN
# 112              TOTAL CRIMES  17962  18462.0   NaN     17733.0   NaN
# 113                   Runaway    395    450.0   NaN       404.0   NaN
# 114            Missing Person    103    145.0   NaN       118.0   NaN
#
#      Unnamed: 6 2020  Unnamed: 8  2021  ...  2022  Unnamed: 12  2023  \
# ...

# %%
print(df.columns.tolist())
## Reference https://stackoverflow.com/questions/49188960/how-to-show-all-columns-names-on-a-large-pandas-dataframe
# Out:
# ['01/15', 2016, 2017, 2018, 'Unnamed: 4', 2019, 'Unnamed: 6', 2020, 'Unnamed: 8', 2021, 'Unnamed: 10', 2022, 'Unnamed: 12', 2023, 'Unnamed: 14', 2024, 'Unnamed: 16', '(+/-)', 'Unnamed: 18', '%', 'Unnamed: 20']

# %%
check_cols = ['01/15', 2016, 2017, 2018, 'Unnamed: 4', 2019, 'Unnamed: 6', 2020, 'Unnamed: 8', 2021, 'Unnamed: 10', 2022, 'Unnamed: 12', 2023, 'Unnamed: 14', 2024, 'Unnamed: 16', '(+/-)', 'Unnamed: 18', '%', 'Unnamed: 20']  # if only need to check a subset of cols for validity, do it here

# %%
df = df.astype(str) #convert all columns to strings as I have to combine numbers in the same cell

# %%
df = df.replace('nan','') #get rid of the nan created back to a blank string

# %%
df
# Out:
#                         01/15   2016     2017  2018 Unnamed: 4  2019  \
# 0                    Homicide      2      0.0   2.0              1.0
# 1                        Rape     15      8.0  13.0              2.0
# 2                 Agg Battery      9      9.0   7.0             15.0
# 3                 Agg Assault     16     16.0  13.0             11.0
# 4    Shooting Into Dwell/Auto     16     19.0  18.0              8.0
# ..                        ...    ...      ...   ...        ...   ...
# 110                     Other    588    708.0           1391.0
# 111   TOTAL NON-TARGET CRIMES   9294   9629.0           9668.0
# 112              TOTAL CRIMES  17962  18462.0          17733.0
# 113                   Runaway    395    450.0            404.0
# 114            Missing Person    103    145.0            118.0
#
#     Unnamed: 6 2020 Unnamed: 8  2021  ...  2022 Unnamed: 12  2023 Unnamed: 14  \
# 0                 1              2.0  ...   2.0               0.0
# ...

# %%
# Combine 'Column1' and 'Column2' into a new column 'Combined'
df['2018'] = df[2018].astype(str) + df['Unnamed: 4']
df['2019'] = df[2019].astype(str) + df['Unnamed: 6']
df['2020'] = df[2020].astype(str) + df['Unnamed: 8']
df['2021'] = df[2021].astype(str) + df['Unnamed: 10']
df['2022'] = df[2022].astype(str) + df['Unnamed: 12']
df['2023'] = df[2023].astype(str) + df['Unnamed: 14']
df['2024'] = df[2024].astype(str) + df['Unnamed: 16']
df['(+/-)'] = df['(+/-)'].astype(str) + df['Unnamed: 18']
df['%'] = df['%'].astype(str) + df['Unnamed: 20']

# %%
df = df.drop(columns=[2018, 'Unnamed: 4', 2019, 'Unnamed: 6', 2020, 'Unnamed: 8', 2021, 'Unnamed: 10', 2022, 'Unnamed: 12', 2023, 'Unnamed: 14', 2024, 'Unnamed: 16', '(+/-)', 'Unnamed: 18', '%', 'Unnamed: 20'])

# %%
df
# Out:
#                         01/15   2016     2017     2018     2019     2020  \
# 0                    Homicide      2      0.0      2.0      1.0        1
# 1                        Rape     15      8.0     13.0      2.0        6
# 2                 Agg Battery      9      9.0      7.0     15.0        9
# 3                 Agg Assault     16     16.0     13.0     11.0       13
# 4    Shooting Into Dwell/Auto     16     19.0     18.0      8.0        7
# ..                        ...    ...      ...      ...      ...      ...
# 110                     Other    588    708.0   1391.0   1665.0   1602.0
# 111   TOTAL NON-TARGET CRIMES   9294   9629.0   9668.0   9327.0   9517.0
# 112              TOTAL CRIMES  17962  18462.0  17733.0  17020.0  18128.0
# 113                   Runaway    395    450.0    404.0    412.0    391.0
# 114            Missing Person    103    145.0    118.0    154.0    144.0
#
#         2021     2022     2023 2024
# 0        2.0      2.0      0.0    0
# ...

# %%
df_transposed = df.transpose()  # or df.transpose()
df_transposed
## Reference https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.transpose.html
# Out:
#             0     1            2            3                         4    \
# 01/15  Homicide  Rape  Agg Battery  Agg Assault  Shooting Into Dwell/Auto
# 2016          2    15            9           16                        16
# 2017        0.0   8.0          9.0         16.0                      19.0
# 2018        2.0  13.0          7.0         13.0                      18.0
# 2019        1.0   2.0         15.0         11.0                       8.0
# 2020          1     6            9           13                         7
# 2021        2.0   5.0         15.0         17.0                      15.0
# 2022        2.0   6.0         23.0         35.0                      25.0
# 2023        0.0   4.0         18.0         35.0                      17.0
# 2024          0     1            3           10                         8
#
#                       5                  6                     7        8    \
# 01/15  Shooting-Occ Dwell  Shooting-Occ Auto  Shooting-Unocc Dwell  Robbery
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_excel("C://Users//hlcma//OneDrive//Desktop//KCKPD/KCKPD-YTD-STATS-1-15-24/KCKPD-YTD-STATS-1-15-24.xlsx", header=2)
## Header is of two rows with the Pivot table
## Reference Link: https://stackoverflow.com/questions/37400974/error-unicode-error-unicodeescape-codec-cant-decode-bytes-in-position-2-3
## Reference Link: https://saturncloud.io/blog/how-to-use-python-and-pandas-to-convert-xlsx-to-csv-and-remove-the-index-column/

df = df.astype(str) #convert all columns to strings as I have to combine numbers in the same cell
df = df.replace('nan','') #get rid of the nan created back to a blank string

# Combine 'Column1' and 'Column2' into a new column 'Combined'
df['2018'] = df[2018].astype(str) + df['Unnamed: 4']
df['2019'] = df[2019].astype(str) + df['Unnamed: 6']
df['2020'] = df[2020].astype(str) + df['Unnamed: 8']
df['2021'] = df[2021].astype(str) + df['Unnamed: 10']
df['2022'] = df[2022].astype(str) + df['Unnamed: 12']
df['2023'] = df[2023].astype(str) + df['Unnamed: 14']
df['2024'] = df[2024].astype(str) + df['Unnamed: 16']
df['(+/-)'] = df['(+/-)'].astype(str) + df['Unnamed: 18']
df['%'] = df['%'].astype(str) + df['Unnamed: 20']

df = df.drop(columns=[2018, 'Unnamed: 4', 2019, 'Unnamed: 6', 2020, 'Unnamed: 8', 2021, 'Unnamed: 10', 2022, 'Unnamed: 12', 2023, 'Unnamed: 14', 2024, 'Unnamed: 16', '(+/-)', 'Unnamed: 18', '%', 'Unnamed: 20'])

df_transposed = df.transpose()  # or df.transpose()
df_transposed
## Reference https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.transpose.html
# Out:
#             0     1            2            3                         4    \
# 01/15  Homicide  Rape  Agg Battery  Agg Assault  Shooting Into Dwell/Auto
# 2016          2    15            9           16                        16
# 2017        0.0   8.0          9.0         16.0                      19.0
# 2018        2.0  13.0          7.0         13.0                      18.0
# 2019        1.0   2.0         15.0         11.0                       8.0
# 2020          1     6            9           13                         7
# 2021        2.0   5.0         15.0         17.0                      15.0
# 2022        2.0   6.0         23.0         35.0                      25.0
# 2023        0.0   4.0         18.0         35.0                      17.0
# 2024          0     1            3           10                         8
#
#                       5                  6                     7        8    \
# 01/15  Shooting-Occ Dwell  Shooting-Occ Auto  Shooting-Unocc Dwell  Robbery
# ...
